# %% [markdown]
# <a href="https://colab.research.google.com/github/sarah0211-02/Assignment1_Publication-GradePlot/blob/main/PYTN_Assgn_1_Batch3_SyahraniNabillaPardede.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exploring Datasets With Pandas

# %% [markdown]
# ##Import Library and Processing Data

# %% [markdown]
# ###Numpy dan Pandas

# %%
#import library pandas dan numpy
import numpy as np
import pandas as pd
from google.colab import files
filenya=files.upload()
# Out:
#      <input type="file" id="files-9cdeede0-c9ea-4c91-9443-aee4e6b92370" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9cdeede0-c9ea-4c91-9443-aee4e6b92370">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ###Ambil data dan baca data

# %%
# Ambil Data
df = pd.read_csv("london_crime_by_lsoa.csv")

# Baca Data
df
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %% [markdown]
# ###Melihat jumlah data dan kolom

# %%
df.shape
# Out:
# (13490604, 7)

# %% [markdown]
# **Keterangan**
# Dari df.shape dapat dihasilkan bahwa data london_crime_by_lsoa memiliki 13490604 data dan memiliki 7 kolom di dalamnya

# %% [markdown]
# ##Getting to know about the data

# %% [markdown]
# ###Displaying Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 720.5+ MB

# %%
df.index.values
# Out:
# array([       0,        1,        2, ..., 13490601, 13490602, 13490603])

# %% [markdown]
# **Keterangan**
# Dari values tersebut dapat dilihat ternyata terdapat nilai 0 pada kolom value yang dimana apakah data tersebut benar bernilai 0 atau memang terdapat kesalahan dalam pengisian data. Sehingga mengganti nilai value yang bernilai 0 tersebut dengan menambahkannya dengan angka 1, dengan asumsi kolom major_category dan minor_category mempunyai nilai

# %% [markdown]
# ##Querying london_crime_by_lsoa datasets

# %%
df_not_null_data = df[df["value"] == 1]

# %%
df_not_null_data
# Out:
#           lsoa_code               borough               major_category  \
# 9         E01004177                Sutton           Theft and Handling
# 16        E01000086  Barking and Dagenham           Theft and Handling
# 25        E01001794               Hackney  Violence Against the Person
# 32        E01000733               Bromley              Criminal Damage
# 43        E01001193               Croydon           Theft and Handling
# ...             ...                   ...                          ...
# 13490566  E01000738               Bromley                     Burglary
# 13490572  E01033735             Greenwich              Criminal Damage
# 13490584  E01003301              Lewisham  Violence Against the Person
# 13490590  E01001679             Greenwich           Theft and Handling
# 13490600  E01002504            Hillingdon                      Robbery
#
#                             minor_category  value  year  month
# ...

# %% [markdown]
# ##Showing Basic Statistic

# %%
df_not_null_data.describe()
# Out:
#            value          year         month
# count  2141789.0  2.141789e+06  2.141789e+06
# mean         1.0  2.012015e+03  6.507797e+00
# std          0.0  2.599081e+00  3.425987e+00
# min          1.0  2.008000e+03  1.000000e+00
# 25%          1.0  2.010000e+03  4.000000e+00
# 50%          1.0  2.012000e+03  7.000000e+00
# 75%          1.0  2.014000e+03  9.000000e+00
# max          1.0  2.016000e+03  1.200000e+01

# %% [markdown]
# ##Exploring london_crime_by_lsoa datasets

# %%
df_not_null_data["borough"].value_counts()
# Out:
# Croydon                   94786
# Lambeth                   92277
# Ealing                    87985
# Southwark                 85661
# Barnet                    83693
# Newham                    82695
# Lewisham                  81911
# Brent                     80637
# Enfield                   77162
# Wandsworth                77134
# Bromley                   73163
# Waltham Forest            71396
# Tower Hamlets             71257
# Hackney                   71207
# Haringey                  70662
# Hillingdon                68604
# Redbridge                 67682
# Greenwich                 66340
# Hounslow                  66061
# Islington                 65069
# Camden                    63721
# Westminster               57206
# Hammersmith and Fulham    55175
# Havering                  55102
# Barking and Dagenham      54501
# Bexley                    51715
# Harrow                    50786
# Merton                    50453
# Kensington and Chelsea    47735
# ...

# %%
df_not_null_data["major_category"].value_counts()
# Out:
# Theft and Handling             662379
# Violence Against the Person    544226
# Criminal Damage                353769
# Burglary                       263035
# Drugs                          138878
# Robbery                        110785
# Other Notifiable Offences       65925
# Fraud or Forgery                 1835
# Sexual Offences                   957
# Name: major_category, dtype: int64

# %%
df_not_null_data["minor_category"].value_counts()
# Out:
# Burglary in a Dwelling                    154845
# Theft From Motor Vehicle                  151633
# Assault with Injury                       138647
# Other Theft                               136743
# Common Assault                            135116
# Harassment                                135016
# Criminal Damage To Motor Vehicle          124756
# Theft/Taking Of Motor Vehicle             122568
# Possession Of Drugs                       112104
# Burglary in Other Buildings               108190
# Criminal Damage To Dwelling                96217
# Personal Property                          92874
# Other Criminal Damage                      88923
# Other Theft Person                         77223
# Theft/Taking of Pedal Cycle                72838
# Wounding/GBH                               68261
# Other Notifiable                           61176
# Theft From Shops                           45207
# Criminal Damage To Other Building          43873
# ...

# %%
df_not_null_data["year"].value_counts()
# Out:
# 2016    246170
# 2015    241347
# 2008    240966
# 2009    238097
# 2014    237515
# 2010    235513
# 2011    234747
# 2012    234714
# 2013    232720
# Name: year, dtype: int64

# %%
df_not_null_data["month"].value_counts()
# Out:
# 7     183417
# 5     182511
# 6     182374
# 10    182276
# 3     179212
# 9     178645
# 11    178348
# 8     178316
# 4     178181
# 1     174978
# 2     171902
# 12    171629
# Name: month, dtype: int64

# %% [markdown]
# **Keterangan**
# Dari hasil Exploring london_crime_by_lsoa dataset dapat dihasilkan sebuah informasi sebagai berikut:
#
# * Pada kolom borough tindak kejahatan terendah berada di "City of London" dan tingkat kejahatan tertinggi berada di "Croydon"
# * Pada kolom major_category headline kejahatan terendah merupakan kejahatan "Sexual Offences" dan headline kejahatan tertinggi merupakan kejahatan "Theft and Handling"
# * Pada kolom minor_category headline kejahatan terendah merupakan kejahatan "Rape" dan headline kejatahan tertinggi merupakan kejahatan "Burglary in a Dwelling"
# * Pada kolom year tindak kejahatan tertinggi berada di tahun 2016 dan kejahatan terendah berada di 2013
# * Pada kolom Month tindak kejahatan tertinggi berada di bulan ke - 7 dan kejahatan terendah berada di bulan ke - 12

# %% [markdown]
# **Pertanyaan:**
#
# Tindak kejahatan apa saja yang terjadi pada tahun 2013?

# %% [markdown]
# ##Advanced Processing Data

# %% [markdown]
# ###Mendapatkan informasi data major_category yang terjadi tahun 2013

# %%
borough_major_category_2013 = df_not_null_data[["borough", "major_category"]][df_not_null_data.year == 2013].value_counts().sort_values(ascending=False)

borough_major_category_2013
# Out:
# borough         major_category
# Wandsworth      Theft and Handling           3086
# Lambeth         Theft and Handling           3078
# Croydon         Theft and Handling           3003
# Southwark       Theft and Handling           2977
# Barnet          Theft and Handling           2869
#                                              ...
# City of London  Drugs                           4
#                 Criminal Damage                 3
#                 Robbery                         3
#                 Other Notifiable Offences       2
#                 Burglary                        1
# Length: 231, dtype: int64

# %% [markdown]
# ###Mendapatkan informasi data minor_category yang terjadu pada tahun 2013

# %%
minor_category_2013 = df_not_null_data[["borough", "minor_category"]][df_not_null_data.year == 2013].value_counts().sort_values(ascending=False)

minor_category_2013
# Out:
# borough               minor_category
# Bromley               Burglary in a Dwelling               800
# Croydon               Theft From Motor Vehicle             798
#                       Burglary in a Dwelling               794
# Barnet                Burglary in a Dwelling               779
# Ealing                Burglary in a Dwelling               761
#                                                           ...
# Sutton                Murder                                 1
# Hillingdon            Murder                                 1
# Richmond upon Thames  Murder                                 1
# City of London        Criminal Damage To Other Building      1
# Merton                Murder                                 1
# Length: 910, dtype: int64

# %% [markdown]
# **Keterangan**
# Setelah di dapatkan data konkrit kejahatan yang terjadi pada tahun 2013, selanjutnya adalah untuk menggabungkan setiap kolom dengan batasan kasus yaitu pada tahun 2013

# %%
df_data_on_2013 = df_not_null_data[["borough", "major_category", "minor_category", "year"]][df_not_null_data.year == 2013]

# Cek Data
df_data_on_2013
# Out:
#                        borough               major_category  \
# 25                     Hackney  Violence Against the Person
# 121       Barking and Dagenham                      Robbery
# 371                     Barnet  Violence Against the Person
# 380                   Hounslow  Violence Against the Person
# 446                  Greenwich              Criminal Damage
# ...                        ...                          ...
# 13490350              Hounslow  Violence Against the Person
# 13490474        Waltham Forest           Theft and Handling
# 13490482               Croydon                        Drugs
# 13490500              Havering           Theft and Handling
# 13490572             Greenwich              Criminal Damage
#
#                                   minor_category  year
# 25                                    Harassment  2013
# 121                            Business Property  2013
# 371                                   Harassment  2013
# ...

# %% [markdown]
# ##Area Plot

# %% [markdown]
# ###Import Library

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ###Plot Area

# %%
df_tahun_2013 = df_not_null_data[df_not_null_data["year"].isin([2013])]
df_tahun_2013
# Out:
#           lsoa_code               borough               major_category  \
# 25        E01001794               Hackney  Violence Against the Person
# 121       E01000045  Barking and Dagenham                      Robbery
# 371       E01000188                Barnet  Violence Against the Person
# 380       E01002655              Hounslow  Violence Against the Person
# 446       E01033732             Greenwich              Criminal Damage
# ...             ...                   ...                          ...
# 13490350  E01033084              Hounslow  Violence Against the Person
# 13490474  E01004330        Waltham Forest           Theft and Handling
# 13490482  E01001112               Croydon                        Drugs
# 13490500  E01002333              Havering           Theft and Handling
# 13490572  E01033735             Greenwich              Criminal Damage
#
#                                   minor_category  value  year  month
# ...

# %%
df_maj_year = df_tahun_2013.groupby(["major_category", "borough"]).sum()["value"].sort_values(ascending=False)

# %%
df_maj_year.unstack().T #transpose
# Out:
# major_category          Burglary  Criminal Damage  Drugs  \
# borough
# Barking and Dagenham         716              959    391
# Barnet                      1330             1283    580
# Bexley                       827              918    388
# Brent                       1058             1264    658
# Bromley                     1319             1205    514
# Camden                       857             1027    448
# City of London                 1                3      4
# Croydon                     1307             1639    686
# Ealing                      1224             1374    678
# Enfield                     1151             1247    604
# Greenwich                    942             1256    495
# Hackney                      945             1106    576
# Hammersmith and Fulham       686              752    472
# Haringey                     934             1119    465
# Harrow                       735              736    372
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))
df_maj_year.unstack().T.plot(kind="area",ax=ax,stacked=False)

plt.title('total') # add a title to the area plot
plt.ylabel('value') # add y-label
plt.xlabel('year') # add x-label

plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# **Keterangan**
# Dari Grafik Tipe Area, dapat dilihat bahwasannya tingkat kejahatan yang terjadi di setiap wilayah (borough) pada tahun 2013 adalah Other Notifiable Offences

# %% [markdown]
# ###Plot:Bar

# %%
# Stage dataframe for plotting

df_area = df_tahun_2013.groupby(['borough']).sum()['value'].sort_values(ascending=False)
df_area.plot(kind='bar', figsize=(20,8))

# Set axis to the graphs
plt.title("Borough crime in the 2013") # add a title to the area plot
plt.ylabel('Total Kejahatan') # add y-label
plt.xlabel('Borough') # add x-label

plt.show()

# %% [markdown]
# **Keterangan**
# Dari Grafik Tipe Bar, dapat dilihat bahwasannya tingkat kejahatan yang terjadi pada tahun 2013 sering terjadi di wilayah (borough) Croydon dan kejahatan yang jarang terjadi pada tahun 2013 berada di wilayah City of London

# %%
df_maj = df_tahun_2013.groupby(['month']).sum()['value'].sort_values(ascending=True)

df_maj.plot(kind="bar", figsize=(10,8))
plt.xticks(rotation=40)
plt.title("Kejahatan Pada Tahun 2013 Berdasarkan Bulan") # add a title to the area plot
plt.ylabel("Tingkat Kejahatan") # add y-label
plt.xlabel("Bulan") # add x-label

plt.show()

# %% [markdown]
# **Keterangan**
# Dan untuk kejahatan yang sering terjadi berada di bulan ke 7 dan tindak kejahatan terendah berada di bulan ke 2 pada tahun 2013

# %% [markdown]
# ###Plot:Pie

# %%
# Stage dataframe for plotting

df_area = df_tahun_2013.groupby(['major_category']).sum()['value'].sort_values(ascending=False)
df_area.plot(kind='pie', figsize=(20,8), autopct='%1.0f%%')

# Set axis to the graphs
plt.title("Borough crime in the 2013") # add a title to the area plot
plt.ylabel('Total Kejahatan') # add y-label
plt.xlabel('Borough') # add x-label

plt.show()

# %% [markdown]
# ###Plot: Box

# %%
# Stage dataframe for plotting

df_tahun_2013.month.value_counts().plot(kind='box')

plt.title('Data Crime Yang Terjadi Selama Tahun 2013') # add a title to the area plot
plt.ylabel('Total Kasus') # add y-label
plt.show()

# %% [markdown]
# ###Plot: Histogram

# %%
df_tahun_2013.describe()
# Out:
#           value      year          month
# count  232720.0  232720.0  232720.000000
# mean        1.0    2013.0       6.524630
# std         0.0       0.0       3.421863
# min         1.0    2013.0       1.000000
# 25%         1.0    2013.0       4.000000
# 50%         1.0    2013.0       7.000000
# 75%         1.0    2013.0       9.000000
# max         1.0    2013.0      12.000000

# %% [markdown]
# **Keterangan**
# menghapus data year, dikarenakan titik acuan pada project ini merupakan pada tahun 2013

# %%
df_tahun_2013_no_year = df_tahun_2013.copy()

# %%
del df_tahun_2013_no_year["year"]

# %%
del df_tahun_2013_no_year["value"]

# %%
df_tahun_2013_no_year
# Out:
#           lsoa_code               borough               major_category  \
# 25        E01001794               Hackney  Violence Against the Person
# 121       E01000045  Barking and Dagenham                      Robbery
# 371       E01000188                Barnet  Violence Against the Person
# 380       E01002655              Hounslow  Violence Against the Person
# 446       E01033732             Greenwich              Criminal Damage
# ...             ...                   ...                          ...
# 13490350  E01033084              Hounslow  Violence Against the Person
# 13490474  E01004330        Waltham Forest           Theft and Handling
# 13490482  E01001112               Croydon                        Drugs
# 13490500  E01002333              Havering           Theft and Handling
# 13490572  E01033735             Greenwich              Criminal Damage
#
#                                   minor_category  month
# 25                                    Harassment      2
# ...

# %%
int_data = len(df_tahun_2013)

int_data_eks = np.sqrt(int_data)

int_data_eks = int(int_data_eks)

# %%
fig = plt.figure(figsize = (16,8))
ax = fig.gca()
df_tahun_2013_no_year.hist(ax=ax,bins=8)
plt.show()

# %% [markdown]
# ##Plot: Scatter

# %%
df_bulan = df_tahun_2013.groupby(['month']).sum()['value']
df_bulan
# Out:
# month
# 1     18916
# 2     18547
# 3     19105
# 4     19310
# 5     19731
# 6     19850
# 7     20359
# 8     19418
# 9     19408
# 10    19913
# 11    19523
# 12    18640
# Name: value, dtype: int64

# %%
pd.DataFrame(df_bulan).reset_index().plot(kind='scatter',x='month',y='value', figsize=(10, 6))
plt.title('Number of Criminals by Month')
plt.xlabel('Month')
plt.ylabel('Number of Criminals')
# Out:
# Text(0, 0.5, 'Number of Criminals')

# %% [markdown]
# ##Word Cloud

# %% [markdown]
# ###Import Library

# %%
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud is installed and imported!')
# Out:
# Wordcloud is installed and imported!

# %%
stopwords = set(STOPWORDS)

# %%
df_wordclouds = df[df['year'].isin([2013])]
# df_woc = df_woc[df_woc['borough'].isin(['City of London'])]
df_wordclouds = df_wordclouds['major_category'].str.cat(sep=' ')

df_wordcloud = WordCloud(
    background_color='white',
    stopwords=stopwords
)

# generate word cloud
df_wordcloud.generate(df_wordclouds)

fig = plt.figure()
# set width
fig.set_figwidth(14)
# set height
fig.set_figheight(18)

plt.imshow(df_wordcloud, interpolation='bilinear')

plt.axis('off')
plt.show()

# %% [markdown]
# ##Folium Map

# %% [markdown]
# ###Import Library

# %%
import folium

print('Folium installed and imported!')
# Out:
# Folium installed and imported!

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# London Latitude and longitude values
latitude = 51.509865
longitude = -0.118092

# %%
# create map and display it
london_map = folium.Map(location=[latitude, longitude], zoom_start = 14)

# display the map of San Francisco
london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
